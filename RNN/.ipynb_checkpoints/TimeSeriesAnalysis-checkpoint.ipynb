# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('RSCCASN.csv')

# %%
df
# Out:
#            DATE  RSCCASN
# 0    1992-01-01     6938
# 1    1992-02-01     7524
# 2    1992-03-01     8475
# 3    1992-04-01     9401
# 4    1992-05-01     9558
# ..          ...      ...
# 329  2019-06-01    21123
# 330  2019-07-01    21714
# 331  2019-08-01    23791
# 332  2019-09-01    19695
# 333  2019-10-01    21113
#
# [334 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 334 entries, 0 to 333
# Data columns (total 2 columns):
# DATE       334 non-null object
# RSCCASN    334 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 5.3+ KB

# %%
df = pd.read_csv('RSCCASN.csv', parse_dates=True, index_col='DATE')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 334 entries, 1992-01-01 to 2019-10-01
# Data columns (total 1 columns):
# RSCCASN    334 non-null int64
# dtypes: int64(1)
# memory usage: 5.2 KB

# %%
df.columns = ['Sales']

# %%
df.plot(figsize=(16,10))

# %%
len(df)
# Out:
# 334

# %%
df
# Out:
#             Sales
# DATE
# 1992-01-01   6938
# 1992-02-01   7524
# 1992-03-01   8475
# 1992-04-01   9401
# 1992-05-01   9558
# ...           ...
# 2019-06-01  21123
# 2019-07-01  21714
# 2019-08-01  23791
# 2019-09-01  19695
# 2019-10-01  21113
#
# [334 rows x 1 columns]

# %%
test_size = 18 # in months
test_index = len(df) - test_size

# %%
train = df.iloc[:test_index]
test = df.iloc[test_index:]

# %%
train
# Out:
#             Sales
# DATE
# 1992-01-01   6938
# 1992-02-01   7524
# 1992-03-01   8475
# 1992-04-01   9401
# 1992-05-01   9558
# ...           ...
# 2017-12-01  33720
# 2018-01-01  15881
# 2018-02-01  18585
# 2018-03-01  22404
# 2018-04-01  20616
#
# [316 rows x 1 columns]

# %%
test
# Out:
#             Sales
# DATE
# 2018-05-01  23764
# 2018-06-01  21589
# 2018-07-01  21919
# 2018-08-01  23381
# 2018-09-01  20260
# 2018-10-01  21473
# 2018-11-01  25831
# 2018-12-01  34706
# 2019-01-01  16410
# 2019-02-01  18134
# 2019-03-01  22093
# 2019-04-01  21597
# 2019-05-01  23200
# 2019-06-01  21123
# 2019-07-01  21714
# 2019-08-01  23791
# 2019-09-01  19695
# 2019-10-01  21113

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(train)
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
scaler_train = scaler.transform(train)

# %%
scaler_test = scaler.transform(test)

# %%
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %%
length = 12 # 1 year
batch_size = 1

generator = TimeseriesGenerator(scaler_train, scaler_train,
                               length=length, batch_size=batch_size)

# %%
X, y = generator[0]

# %%
X
# Out:
# array([[[0.        ],
#         [0.02127505],
#         [0.05580163],
#         [0.08942056],
#         [0.09512053],
#         [0.08146965],
#         [0.07860151],
#         [0.12979233],
#         [0.09566512],
#         [0.1203892 ],
#         [0.15426227],
#         [0.41595266]]])

# %%
y
# Out:
# array([[0.02047633]])

# %%
scaler_train[12]
# Out:
# array([0.02047633])

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Dense, LSTM

# %%
n_features =1

# %%
model = Sequential()
model.add(LSTM(100, activation='relu', input_shape=(length, n_features)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 100)               40800
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 40,901
# Trainable params: 40,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
early_stop = EarlyStopping(monitor='val_loss',
                          patience=2)

# %%
validation_generator = TimeseriesGenerator(scaler_test, scaler_test,
                               length=length, batch_size=batch_size)

# %%
model.fit_generator(generator, epochs=20,
                   validation_data=validation_generator,
                   callbacks=[early_stop])
# Out:
# WARNING:tensorflow:From <ipython-input-40-5687c89fb7d5>:3: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 304 steps, validate for 6 steps
# Epoch 1/20
# 304/304 [==============================] - 4s 13ms/step - loss: 0.0243 - val_loss: 0.0140
# Epoch 2/20
# 304/304 [==============================] - 2s 7ms/step - loss: 0.0188 - val_loss: 0.0023
# Epoch 3/20
# 304/304 [==============================] - 2s 6ms/step - loss: 0.0109 - val_loss: 0.0109
# Epoch 4/20
# 304/304 [==============================] - 2s 7ms/step - loss: 0.0039 - val_loss: 0.0019
# Epoch 5/20
# 304/304 [==============================] - 2s 7ms/step - loss: 0.0030 - val_loss: 0.0114
# Epoch 6/20
# 304/304 [==============================] - 2s 7ms/step - loss: 0.0025 - val_loss: 0.0040

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses.plot()

# %%
test_predictions = []
first_eval_batch = scaler_train[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))

for i in range(len(test)):
    current_pred = model.predict(current_batch)[0]
    test_predictions.append(current_pred)
    current_batch = np.append(current_batch[:,1:,:], [[current_pred]], axis=1)

# %%
true_predictions = scaler.inverse_transform(test_predictions)
test['LSTM Predictions'] = true_predictions
# Out:
# /Users/fu777kd/.pythonvenv/tf_practise/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
test.head()
# Out:
#             Sales  LSTM Predictions
# DATE
# 2018-05-01  23764      22814.654977
# 2018-06-01  21589      21560.249365
# 2018-07-01  21919      21804.050931
# 2018-08-01  23381      23910.725261
# 2018-09-01  20260      21208.333613

# %%
test.plot(figsize=(12,8))

# %% [markdown]
# ### Forecast future predictions

# %%
full_scaler = MinMaxScaler()
scaled_full_data = full_scaler.fit_transform(df)

# %%
length = 12

# %%
generator = TimeseriesGenerator(scaled_full_data, scaled_full_data,
                               length=length, batch_size=1)

# %%
model = Sequential()
model.add(LSTM(100, activation='relu', input_shape=(length,n_features)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
model.fit_generator(generator, epochs=10)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 322 steps
# Epoch 1/10
# 322/322 [==============================] - 3s 8ms/step - loss: 0.0237
# Epoch 2/10
# 322/322 [==============================] - 2s 6ms/step - loss: 0.0160
# Epoch 3/10
# 322/322 [==============================] - 2s 7ms/step - loss: 0.0086
# Epoch 4/10
# 322/322 [==============================] - 2s 6ms/step - loss: 0.0040
# Epoch 5/10
# 322/322 [==============================] - 2s 5ms/step - loss: 0.0023
# Epoch 6/10
# 322/322 [==============================] - 2s 5ms/step - loss: 0.0015
# Epoch 7/10
# 322/322 [==============================] - 2s 6ms/step - loss: 0.0020
# Epoch 8/10
# 322/322 [==============================] - 2s 6ms/step - loss: 0.0016
# Epoch 9/10
# 322/322 [==============================] - 2s 6ms/step - loss: 0.0014
# Epoch 10/10
# 322/322 [==============================] - 2s 6ms/step - loss: 0.0016

# %%
forecast = []

periods = 12

first_eval_batch = scaled_full_data[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))

for i in range(periods):
    
    # get prediction 1 time stamp ahead ([0] is for grabbing just the number instead of [array])
    current_pred = model.predict(current_batch)[0]
    
    # store prediction
    forecast.append(current_pred) 
    
    # update batch to now include prediction and drop first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)

# %%
forecast = scaler.inverse_transform(forecast)

# %%
forecast_index = pd.date_range(start='2018-11-01', periods=periods, freq=30)
